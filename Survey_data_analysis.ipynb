# %% [markdown]
# ## Loading libraries

# %%
# Import the relevant libraries

import pandas as pd
pd.set_option('display.max_rows', 100)

# %%
pwd
# Out:
# '/Users/joannakuc/coding/ssri'

# %% [markdown]
# ## Create DataFrames from excel sheets containing data

# %%
# Create data frames out of cohort 1 data excel sheets

c1_baseline = pd.read_excel('cohort 1.xlsx', sheet_name='cohort 1-baseline')
c1_acute = pd.read_excel('cohort 1.xlsx', sheet_name='cohort1-Acute')
c1_post = pd.read_excel('cohort 1.xlsx', sheet_name='Cohort1-4 week')

# %%
# Create dataframes out of cohort 2 data excel sheets

c2_baseline = pd.read_excel('cohort 2.xlsx', sheet_name='cohort 2-baseline')
c2_acute = pd.read_excel('cohort 2.xlsx', sheet_name='cohort 2-acute')
c2_post = pd.read_excel('cohort 2.xlsx', sheet_name='Cohort 2-4 weeks')

# %%
# Create dataframes out of ceremony data excel sheets

ceremony_baseline = pd.read_excel('ceremony.xlsx', sheet_name='Baseline')
ceremony_acute_1 = pd.read_excel('ceremony.xlsx', sheet_name='Acute-1')
ceremony_acute_2 = pd.read_excel('ceremony.xlsx', sheet_name='Acute-2')
ceremony_acute_3 = pd.read_excel('ceremony.xlsx', sheet_name='Acute-3')
ceremony_acute_4 = pd.read_excel('ceremony.xlsx', sheet_name='Acute-4')
ceremony_acute_5 = pd.read_excel('ceremony.xlsx', sheet_name='Acute-5')
ceremony_post = pd.read_excel('ceremony.xlsx', sheet_name='4 weeks')

# %%
# This will remove rows where NaNs are in 'URL Variable: sguid' column

c1_baseline = c1_baseline.dropna(subset=['URL Variable: sguid'])
c1_acute = c1_acute.dropna(subset=['URL Variable: sguid'])
c1_post = c1_post.dropna(subset=['URL Variable: sguid'])

c2_baseline = c2_baseline.dropna(subset=['URL Variable: sguid'])
c2_acute = c2_acute.dropna(subset=['URL Variable: sguid'])
c2_post = c2_post.dropna(subset=['URL Variable: sguid'])

ceremony_baseline = ceremony_baseline.dropna(subset=['URL Variable: sguid'])
ceremony_acute_1 = ceremony_acute_1.dropna(subset=['URL Variable: sguid'])
ceremony_acute_2 = ceremony_acute_2.dropna(subset=['URL Variable: sguid'])
ceremony_acute_3 = ceremony_acute_3.dropna(subset=['URL Variable: sguid'])
ceremony_acute_4 = ceremony_acute_4.dropna(subset=['URL Variable: sguid'])
ceremony_acute_5 = ceremony_acute_5.dropna(subset=['URL Variable: sguid'])
ceremony_post = ceremony_post.dropna(subset=['URL Variable: sguid'])

# %% [markdown]
# ## Merging datasets together

# %%
# This will set the 'URL Variable: sguid' as index (i.e, column 0).

# Each survey participant has a unique 'URL Variable: sguid' and this is what
# should be used to track their responses through time.

# This operation is necessary to later merge the different timepoints
# and match them by participants.

# The following rows will set URL Variable: sguid as index for cohort 1

c1_baseline.set_index('URL Variable: sguid', inplace=True, drop=True)
c1_acute.set_index('URL Variable: sguid', inplace=True, drop=True)
c1_post.set_index('URL Variable: sguid', inplace=True, drop=True)

# The following rows will set Response ID as index for cohort 2

c2_baseline.set_index('URL Variable: sguid', inplace=True, drop=True)
c2_acute.set_index('URL Variable: sguid', inplace=True, drop=True)
c2_post.set_index('URL Variable: sguid', inplace=True, drop=True)

# The following rows will set Response ID as index for ceremony data

ceremony_baseline.set_index('URL Variable: sguid', inplace=True, drop=True)
ceremony_acute_1.set_index('URL Variable: sguid', inplace=True, drop=True)
ceremony_acute_2.set_index('URL Variable: sguid', inplace=True, drop=True)
ceremony_acute_3.set_index('URL Variable: sguid', inplace=True, drop=True)
ceremony_acute_4.set_index('URL Variable: sguid', inplace=True, drop=True)
ceremony_acute_5.set_index('URL Variable: sguid', inplace=True, drop=True)
ceremony_post.set_index('URL Variable: sguid', inplace=True, drop=True)

# %%
# Please note that due to overlapping numbering of rows in both cohorts,
# we will add number '2000' to the Response ID for cohort 2 subjects.
# This will allow us to easily distinguish between the cohorts.

# This means data for every Subject ID > 2000 is from cohort 2

# 2000 is a random number chosen just to make it easy, 
# there is no other logic behind that choice. 

c2_baseline[["Response ID"]] = c2_baseline[["Response ID"]] + 2000
c2_acute[["Response ID"]] = c2_acute[["Response ID"]] + 2000
c2_post[["Response ID"]] = c2_post[["Response ID"]] + 2000

# %%
# First let's merge cohort 1 and cohort 2 data because these datasets 
# have more similar timepoints than ceremony study. 

# The concat function is a clever function which allows joining 
# different dataframes into 1. The phrase "axis = 0" tells the 
# function to merge the dataframes vertically (i.e., add more rows). 

baseline = pd.concat([c1_baseline, c2_baseline], axis=0)
acute = pd.concat([c1_acute, c2_acute], axis=0)
post = pd.concat([c1_post, c2_post], axis=0)

# %%
# Here we once again use the concat function, but through specifying that 
# "axis = 1" we tell the function that we want to merge the data frames 
# horizontally, i.e. add more columns.

c1_c2 = pd.concat([baseline, acute, post], axis=1)
c1_c2
# Out:
#                                   Response ID              Time Started  \
# URL Variable: sguid
# S0L9M3dwusvrTy2gXZMJluOr9ZNfq9G5         68.0  Mar 12, 2017 12:28:55 pm
# 0d2Ei33sA5FI6lPfSvj2Cd6WI74Mz8Kn         69.0  Mar 12, 2017 11:41:16 pm
# 97FRaFPDpdCdJi6YL9vxDJ9zj2q5LhJf         70.0   Mar 13, 2017 4:27:39 am
# 45WfRJ6dFFDP3yzjxRCUDtMvzFUzMD19         71.0  Mar 13, 2017 12:54:28 pm
# CALxcCvxQuZUHe4NUU8D0ARZyK1BAvAW         72.0   Mar 13, 2017 6:56:50 pm
# ...                                       ...                       ...
# Tq7JzFnHzZtTRTj2                          NaN                       NaN
# FnafwU24WNsajpTZ                          NaN                       NaN
# IaIlEW6dlKxpu6SC                          NaN                       NaN
# J8FRqdya59eAx6Cv                          NaN                       NaN
# RrmjsV89nn5nri5Q                          NaN                       NaN
#
#                                            Date Submitted Language Referer  \
# URL Variable: sguid
# S0L9M3dwusvrTy2gXZMJluOr9ZNfq9G5  Mar 12, 2017 1:26:46 pm  English     NaN
# 0d2Ei33sA5FI6lPfSvj2Cd6WI74Mz8Kn  Mar 13, 2017 1:20:42 am  English     NaN
# 97FRaFPDpdCdJi6YL9vxDJ9zj2q5LhJf  Mar 13, 2017 5:07:24 am  English     NaN
# 45WfRJ6dFFDP3yzjxRCUDtMvzFUzMD19  Mar 13, 2017 1:44:59 pm  English     NaN
# CALxcCvxQuZUHe4NUU8D0ARZyK1BAvAW  Mar 13, 2017 7:26:29 pm  English     NaN
# ...                                                   ...      ...     ...
# Tq7JzFnHzZtTRTj2                                      NaN      NaN     NaN
# FnafwU24WNsajpTZ                                      NaN      NaN     NaN
# IaIlEW6dlKxpu6SC                                      NaN      NaN     NaN
# J8FRqdya59eAx6Cv                                      NaN      NaN     NaN
# RrmjsV89nn5nri5Q                                      NaN      NaN     NaN
#
#                                  Extended Referer  \
# URL Variable: sguid
# S0L9M3dwusvrTy2gXZMJluOr9ZNfq9G5              NaN
# 0d2Ei33sA5FI6lPfSvj2Cd6WI74Mz8Kn              NaN
# 97FRaFPDpdCdJi6YL9vxDJ9zj2q5LhJf              NaN
# 45WfRJ6dFFDP3yzjxRCUDtMvzFUzMD19              NaN
# CALxcCvxQuZUHe4NUU8D0ARZyK1BAvAW              NaN
# ...                                           ...
# Tq7JzFnHzZtTRTj2                              NaN
# FnafwU24WNsajpTZ                              NaN
# IaIlEW6dlKxpu6SC                              NaN
# J8FRqdya59eAx6Cv                              NaN
# RrmjsV89nn5nri5Q                              NaN
#
#                                                          SessionID  \
# URL Variable: sguid
# S0L9M3dwusvrTy2gXZMJluOr9ZNfq9G5  895484026ce48355fa32c9c063712bc9
# 0d2Ei33sA5FI6lPfSvj2Cd6WI74Mz8Kn  864977194cc24f801c10dbb87c4c849b
# 97FRaFPDpdCdJi6YL9vxDJ9zj2q5LhJf  345742f699ab1b82af25af9cc7ca35b9
# 45WfRJ6dFFDP3yzjxRCUDtMvzFUzMD19  82cad9ff2327df388810ec22da577709
# CALxcCvxQuZUHe4NUU8D0ARZyK1BAvAW  a28b5a2d5e03076a1713b815b24ca3a4
# ...                                                            ...
# Tq7JzFnHzZtTRTj2                                               NaN
# FnafwU24WNsajpTZ                                               NaN
# IaIlEW6dlKxpu6SC                                               NaN
# J8FRqdya59eAx6Cv                                               NaN
# RrmjsV89nn5nri5Q                                               NaN
#
#                                       IP Address  Longitude   Latitude  ...  \
# URL Variable: sguid                                                     ...
# S0L9M3dwusvrTy2gXZMJluOr9ZNfq9G5  109.156.100.70  -0.135100  51.564899  ...
# 0d2Ei33sA5FI6lPfSvj2Cd6WI74Mz8Kn  192.222.176.86 -71.250000  46.799999  ...
# 97FRaFPDpdCdJi6YL9vxDJ9zj2q5LhJf   71.192.44.160 -72.693901  42.329399  ...
# 45WfRJ6dFFDP3yzjxRCUDtMvzFUzMD19    92.40.52.192  -0.122400  51.496399  ...
# CALxcCvxQuZUHe4NUU8D0ARZyK1BAvAW  90.200.237.127  -3.350000  56.116699  ...
# ...                                          ...        ...        ...  ...
# Tq7JzFnHzZtTRTj2                             NaN        NaN        NaN  ...
# FnafwU24WNsajpTZ                             NaN        NaN        NaN  ...
# IaIlEW6dlKxpu6SC                             NaN        NaN        NaN  ...
# J8FRqdya59eAx6Cv                             NaN        NaN        NaN  ...
# RrmjsV89nn5nri5Q                             NaN        NaN        NaN  ...
#
#                                  I've been able to make up my own mind about things.   \
# URL Variable: sguid
# S0L9M3dwusvrTy2gXZMJluOr9ZNfq9G5                                                NaN
# 0d2Ei33sA5FI6lPfSvj2Cd6WI74Mz8Kn                                              Often
# 97FRaFPDpdCdJi6YL9vxDJ9zj2q5LhJf                                                NaN
# 45WfRJ6dFFDP3yzjxRCUDtMvzFUzMD19                                              Often
# CALxcCvxQuZUHe4NUU8D0ARZyK1BAvAW                                                NaN
# ...                                                                             ...
# Tq7JzFnHzZtTRTj2                                                   Some of the time
# FnafwU24WNsajpTZ                                                              Often
# IaIlEW6dlKxpu6SC                                                              Often
# J8FRqdya59eAx6Cv                                                    All of the time
# RrmjsV89nn5nri5Q                                                   Some of the time
#
#                                  I've been feeling loved.   \
# URL Variable: sguid
# S0L9M3dwusvrTy2gXZMJluOr9ZNfq9G5                        NaN
# 0d2Ei33sA5FI6lPfSvj2Cd6WI74Mz8Kn                     Rarely
# 97FRaFPDpdCdJi6YL9vxDJ9zj2q5LhJf                        NaN
# 45WfRJ6dFFDP3yzjxRCUDtMvzFUzMD19           Some of the time
# CALxcCvxQuZUHe4NUU8D0ARZyK1BAvAW                        NaN
# ...                                                     ...
# Tq7JzFnHzZtTRTj2                           Some of the time
# FnafwU24WNsajpTZ                            All of the time
# IaIlEW6dlKxpu6SC                                      Often
# J8FRqdya59eAx6Cv                                      Often
# RrmjsV89nn5nri5Q                           Some of the time
#
#                                  I've been interested in new things.   \
# URL Variable: sguid
# S0L9M3dwusvrTy2gXZMJluOr9ZNfq9G5                                   NaN
# 0d2Ei33sA5FI6lPfSvj2Cd6WI74Mz8Kn                      Some of the time
# 97FRaFPDpdCdJi6YL9vxDJ9zj2q5LhJf                                   NaN
# 45WfRJ6dFFDP3yzjxRCUDtMvzFUzMD19                       All of the time
# CALxcCvxQuZUHe4NUU8D0ARZyK1BAvAW                                   NaN
# ...                                                                ...
# Tq7JzFnHzZtTRTj2                                                   NaN
# FnafwU24WNsajpTZ                                                   NaN
# IaIlEW6dlKxpu6SC                                                   NaN
# J8FRqdya59eAx6Cv                                                   NaN
# RrmjsV89nn5nri5Q                                                   NaN
#
#                                  I've been feeling cheerful.   \
# URL Variable: sguid
# S0L9M3dwusvrTy2gXZMJluOr9ZNfq9G5                           NaN
# 0d2Ei33sA5FI6lPfSvj2Cd6WI74Mz8Kn                        Rarely
# 97FRaFPDpdCdJi6YL9vxDJ9zj2q5LhJf                           NaN
# 45WfRJ6dFFDP3yzjxRCUDtMvzFUzMD19                         Often
# CALxcCvxQuZUHe4NUU8D0ARZyK1BAvAW                           NaN
# ...                                                        ...
# Tq7JzFnHzZtTRTj2                                         Often
# FnafwU24WNsajpTZ                                         Often
# IaIlEW6dlKxpu6SC                              Some of the time
# J8FRqdya59eAx6Cv                                         Often
# RrmjsV89nn5nri5Q                              Some of the time
#
#                                   Did you have more than one psychedelic session/ceremony/experience in the past four weeks?  \
# URL Variable: sguid
# S0L9M3dwusvrTy2gXZMJluOr9ZNfq9G5                                                NaN
# 0d2Ei33sA5FI6lPfSvj2Cd6WI74Mz8Kn                                                NaN
# 97FRaFPDpdCdJi6YL9vxDJ9zj2q5LhJf                                                NaN
# 45WfRJ6dFFDP3yzjxRCUDtMvzFUzMD19                                                NaN
# CALxcCvxQuZUHe4NUU8D0ARZyK1BAvAW                                                NaN
# ...                                                                             ...
# Tq7JzFnHzZtTRTj2                                                                Yes
# FnafwU24WNsajpTZ                                                                 No
# IaIlEW6dlKxpu6SC                                                                Yes
# J8FRqdya59eAx6Cv                                                                Yes
# RrmjsV89nn5nri5Q                                                                Yes
#
#                                   Can you indicate how many more experiences you have had within the past four weeks?  \
# URL Variable: sguid
# S0L9M3dwusvrTy2gXZMJluOr9ZNfq9G5                                                NaN
# 0d2Ei33sA5FI6lPfSvj2Cd6WI74Mz8Kn                                                NaN
# 97FRaFPDpdCdJi6YL9vxDJ9zj2q5LhJf                                                NaN
# 45WfRJ6dFFDP3yzjxRCUDtMvzFUzMD19                                                NaN
# CALxcCvxQuZUHe4NUU8D0ARZyK1BAvAW                                                NaN
# ...                                                                             ...
# Tq7JzFnHzZtTRTj2                                                                  4
# FnafwU24WNsajpTZ                                                                NaN
# IaIlEW6dlKxpu6SC                                                                  1
# J8FRqdya59eAx6Cv                                                                  4
# RrmjsV89nn5nri5Q                                                                  2
#
#                                   Apart from your psychedelic experience, have you experienced any other significant life events that impacted your well-being in a positive way in the past 4 weeks?  \
# URL Variable: sguid
# S0L9M3dwusvrTy2gXZMJluOr9ZNfq9G5                                                NaN
# 0d2Ei33sA5FI6lPfSvj2Cd6WI74Mz8Kn                                                NaN
# 97FRaFPDpdCdJi6YL9vxDJ9zj2q5LhJf                                                NaN
# 45WfRJ6dFFDP3yzjxRCUDtMvzFUzMD19                                                NaN
# CALxcCvxQuZUHe4NUU8D0ARZyK1BAvAW                                                NaN
# ...                                                                             ...
# Tq7JzFnHzZtTRTj2                                                                Yes
# FnafwU24WNsajpTZ                                                                 No
# IaIlEW6dlKxpu6SC                                                                Yes
# J8FRqdya59eAx6Cv                                                                 No
# RrmjsV89nn5nri5Q                                                                 No
#
#                                   Apart from your psychedelic experience, have you experienced any other significant life events that impacted your well-being in a negative way in the past 4 weeks?  \
# URL Variable: sguid
# S0L9M3dwusvrTy2gXZMJluOr9ZNfq9G5                                                NaN
# 0d2Ei33sA5FI6lPfSvj2Cd6WI74Mz8Kn                                                NaN
# 97FRaFPDpdCdJi6YL9vxDJ9zj2q5LhJf                                                NaN
# 45WfRJ6dFFDP3yzjxRCUDtMvzFUzMD19                                                NaN
# CALxcCvxQuZUHe4NUU8D0ARZyK1BAvAW                                                NaN
# ...                                                                             ...
# Tq7JzFnHzZtTRTj2                                                                 No
# FnafwU24WNsajpTZ                                                                Yes
# IaIlEW6dlKxpu6SC                                                                Yes
# J8FRqdya59eAx6Cv                                                                 No
# RrmjsV89nn5nri5Q                                                                 No
#
#                                   To what extend did this/these event(s) influence your overall well-being?  \
# URL Variable: sguid
# S0L9M3dwusvrTy2gXZMJluOr9ZNfq9G5                                                NaN
# 0d2Ei33sA5FI6lPfSvj2Cd6WI74Mz8Kn                                                NaN
# 97FRaFPDpdCdJi6YL9vxDJ9zj2q5LhJf                                                NaN
# 45WfRJ6dFFDP3yzjxRCUDtMvzFUzMD19                                                NaN
# CALxcCvxQuZUHe4NUU8D0ARZyK1BAvAW                                                NaN
# ...                                                                             ...
# Tq7JzFnHzZtTRTj2                                                                NaN
# FnafwU24WNsajpTZ                                                               60.0
# IaIlEW6dlKxpu6SC                                                               80.0
# J8FRqdya59eAx6Cv                                                                NaN
# RrmjsV89nn5nri5Q                                                                NaN
#
#                                  I am interested in new things. 
# URL Variable: sguid
# S0L9M3dwusvrTy2gXZMJluOr9ZNfq9G5                              NaN
# 0d2Ei33sA5FI6lPfSvj2Cd6WI74Mz8Kn                              NaN
# 97FRaFPDpdCdJi6YL9vxDJ9zj2q5LhJf                              NaN
# 45WfRJ6dFFDP3yzjxRCUDtMvzFUzMD19                              NaN
# CALxcCvxQuZUHe4NUU8D0ARZyK1BAvAW                              NaN
# ...                                                           ...
# Tq7JzFnHzZtTRTj2                                            Often
# FnafwU24WNsajpTZ                                            Often
# IaIlEW6dlKxpu6SC                                            Often
# J8FRqdya59eAx6Cv                                            Often
# RrmjsV89nn5nri5Q                                           Rarely
#
# [1386 rows x 412 columns]

# %%
# We might also want to have data frames which contain all of the cohort 1
# and cohort 2 data separately. This may or may not be useful, 
# but good to have it just in case

c1 = pd.concat([c1_baseline, c1_acute, c1_post], axis=1)
c2 = pd.concat([c2_baseline, c2_acute, c2_post], axis=1)

# %%
c2
# Out:
#                                       Response ID              Time Started  \
# URL Variable: sguid
# 58719067-43fe-11e8-8dd6-0a6b0cea1e1e       2011.0   Apr 20, 2018 8:49:36 am
# 3e850dd2-43f1-11e8-8dd6-0a6b0cea1e1e       2012.0   Apr 20, 2018 2:46:57 pm
# 7e15f839-4412-11e8-8dd6-0a6b0cea1e1e       2013.0   Apr 21, 2018 6:25:56 pm
# 2d35d4e3-4414-11e8-8dd6-0a6b0cea1e1e       2014.0  Apr 22, 2018 12:51:15 am
# cad85f8d-44a2-11e8-8dd6-0a6b0cea1e1e       2015.0   Apr 22, 2018 7:01:28 am
# ...                                           ...                       ...
# Tq7JzFnHzZtTRTj2                              NaN                       NaN
# FnafwU24WNsajpTZ                              NaN                       NaN
# IaIlEW6dlKxpu6SC                              NaN                       NaN
# J8FRqdya59eAx6Cv                              NaN                       NaN
# RrmjsV89nn5nri5Q                              NaN                       NaN
#
#                                                 Date Submitted Language  \
# URL Variable: sguid
# 58719067-43fe-11e8-8dd6-0a6b0cea1e1e   Apr 20, 2018 9:21:49 am  English
# 3e850dd2-43f1-11e8-8dd6-0a6b0cea1e1e   Apr 20, 2018 3:40:15 pm  English
# 7e15f839-4412-11e8-8dd6-0a6b0cea1e1e   Apr 21, 2018 7:28:51 pm  English
# 2d35d4e3-4414-11e8-8dd6-0a6b0cea1e1e   Apr 22, 2018 2:07:30 am  English
# cad85f8d-44a2-11e8-8dd6-0a6b0cea1e1e  Apr 22, 2018 11:48:55 am  English
# ...                                                        ...      ...
# Tq7JzFnHzZtTRTj2                                           NaN      NaN
# FnafwU24WNsajpTZ                                           NaN      NaN
# IaIlEW6dlKxpu6SC                                           NaN      NaN
# J8FRqdya59eAx6Cv                                           NaN      NaN
# RrmjsV89nn5nri5Q                                           NaN      NaN
#
#                                                         Referer  \
# URL Variable: sguid
# 58719067-43fe-11e8-8dd6-0a6b0cea1e1e  https://outlook.live.com/
# 3e850dd2-43f1-11e8-8dd6-0a6b0cea1e1e                        NaN
# 7e15f839-4412-11e8-8dd6-0a6b0cea1e1e                        NaN
# 2d35d4e3-4414-11e8-8dd6-0a6b0cea1e1e                        NaN
# cad85f8d-44a2-11e8-8dd6-0a6b0cea1e1e  https://outlook.live.com/
# ...                                                         ...
# Tq7JzFnHzZtTRTj2                                            NaN
# FnafwU24WNsajpTZ                                            NaN
# IaIlEW6dlKxpu6SC                                            NaN
# J8FRqdya59eAx6Cv                                            NaN
# RrmjsV89nn5nri5Q                                            NaN
#
#                                                Extended Referer  \
# URL Variable: sguid
# 58719067-43fe-11e8-8dd6-0a6b0cea1e1e  https://outlook.live.com/
# 3e850dd2-43f1-11e8-8dd6-0a6b0cea1e1e                        NaN
# 7e15f839-4412-11e8-8dd6-0a6b0cea1e1e                        NaN
# 2d35d4e3-4414-11e8-8dd6-0a6b0cea1e1e                        NaN
# cad85f8d-44a2-11e8-8dd6-0a6b0cea1e1e  https://outlook.live.com/
# ...                                                         ...
# Tq7JzFnHzZtTRTj2                                            NaN
# FnafwU24WNsajpTZ                                            NaN
# IaIlEW6dlKxpu6SC                                            NaN
# J8FRqdya59eAx6Cv                                            NaN
# RrmjsV89nn5nri5Q                                            NaN
#
#                                                              SessionID  \
# URL Variable: sguid
# 58719067-43fe-11e8-8dd6-0a6b0cea1e1e  c3afe5c09ce338bc404d63dc0674c60b
# 3e850dd2-43f1-11e8-8dd6-0a6b0cea1e1e  990a581b97bc0ae1696e442c70e73533
# 7e15f839-4412-11e8-8dd6-0a6b0cea1e1e  19e90adad48483d21753f181a074de54
# 2d35d4e3-4414-11e8-8dd6-0a6b0cea1e1e  6b7b664a07f6e26cf59f5a56beddbbdd
# cad85f8d-44a2-11e8-8dd6-0a6b0cea1e1e  22b6abf7de31eaf55e30fff5104ed72c
# ...                                                                ...
# Tq7JzFnHzZtTRTj2                                                   NaN
# FnafwU24WNsajpTZ                                                   NaN
# IaIlEW6dlKxpu6SC                                                   NaN
# J8FRqdya59eAx6Cv                                                   NaN
# RrmjsV89nn5nri5Q                                                   NaN
#
#                                           IP Address  Longitude   Latitude  \
# URL Variable: sguid
# 58719067-43fe-11e8-8dd6-0a6b0cea1e1e  83.226.150.249  18.049999  59.333302
# 3e850dd2-43f1-11e8-8dd6-0a6b0cea1e1e   185.40.184.26  18.049999  59.333302
# 7e15f839-4412-11e8-8dd6-0a6b0cea1e1e   95.199.129.66  18.056000  59.324699
# 2d35d4e3-4414-11e8-8dd6-0a6b0cea1e1e   91.19.192.237   7.700000  47.916698
# cad85f8d-44a2-11e8-8dd6-0a6b0cea1e1e  78.145.227.114  -2.134200  53.466301
# ...                                              ...        ...        ...
# Tq7JzFnHzZtTRTj2                                 NaN        NaN        NaN
# FnafwU24WNsajpTZ                                 NaN        NaN        NaN
# IaIlEW6dlKxpu6SC                                 NaN        NaN        NaN
# J8FRqdya59eAx6Cv                                 NaN        NaN        NaN
# RrmjsV89nn5nri5Q                                 NaN        NaN        NaN
#
#                                       ... I've had energy to spare.  \
# URL Variable: sguid                   ...
# 58719067-43fe-11e8-8dd6-0a6b0cea1e1e  ...                     Often
# 3e850dd2-43f1-11e8-8dd6-0a6b0cea1e1e  ...           All of the time
# 7e15f839-4412-11e8-8dd6-0a6b0cea1e1e  ...          Some of the time
# 2d35d4e3-4414-11e8-8dd6-0a6b0cea1e1e  ...                       NaN
# cad85f8d-44a2-11e8-8dd6-0a6b0cea1e1e  ...          Some of the time
# ...                                   ...                       ...
# Tq7JzFnHzZtTRTj2                      ...          Some of the time
# FnafwU24WNsajpTZ                      ...                     Often
# IaIlEW6dlKxpu6SC                      ...          Some of the time
# J8FRqdya59eAx6Cv                      ...                     Often
# RrmjsV89nn5nri5Q                      ...                    Rarely
#
#                                      I've been dealing with problems well.   \
# URL Variable: sguid
# 58719067-43fe-11e8-8dd6-0a6b0cea1e1e                                   Often
# 3e850dd2-43f1-11e8-8dd6-0a6b0cea1e1e                                   Often
# 7e15f839-4412-11e8-8dd6-0a6b0cea1e1e                                   Often
# 2d35d4e3-4414-11e8-8dd6-0a6b0cea1e1e                                     NaN
# cad85f8d-44a2-11e8-8dd6-0a6b0cea1e1e                                   Often
# ...                                                                      ...
# Tq7JzFnHzZtTRTj2                                            Some of the time
# FnafwU24WNsajpTZ                                            Some of the time
# IaIlEW6dlKxpu6SC                                            Some of the time
# J8FRqdya59eAx6Cv                                                       Often
# RrmjsV89nn5nri5Q                                            Some of the time
#
#                                      I've been thinking clearly.  \
# URL Variable: sguid
# 58719067-43fe-11e8-8dd6-0a6b0cea1e1e                       Often
# 3e850dd2-43f1-11e8-8dd6-0a6b0cea1e1e                       Often
# 7e15f839-4412-11e8-8dd6-0a6b0cea1e1e                       Often
# 2d35d4e3-4414-11e8-8dd6-0a6b0cea1e1e                         NaN
# cad85f8d-44a2-11e8-8dd6-0a6b0cea1e1e                       Often
# ...                                                          ...
# Tq7JzFnHzZtTRTj2                                Some of the time
# FnafwU24WNsajpTZ                                           Often
# IaIlEW6dlKxpu6SC                                Some of the time
# J8FRqdya59eAx6Cv                                           Often
# RrmjsV89nn5nri5Q                                Some of the time
#
#                                      I've been feeling good about myself.   \
# URL Variable: sguid
# 58719067-43fe-11e8-8dd6-0a6b0cea1e1e                                  Often
# 3e850dd2-43f1-11e8-8dd6-0a6b0cea1e1e                        All of the time
# 7e15f839-4412-11e8-8dd6-0a6b0cea1e1e                       Some of the time
# 2d35d4e3-4414-11e8-8dd6-0a6b0cea1e1e                                    NaN
# cad85f8d-44a2-11e8-8dd6-0a6b0cea1e1e                       Some of the time
# ...                                                                     ...
# Tq7JzFnHzZtTRTj2                                           Some of the time
# FnafwU24WNsajpTZ                                           Some of the time
# IaIlEW6dlKxpu6SC                                                      Often
# J8FRqdya59eAx6Cv                                                      Often
# RrmjsV89nn5nri5Q                                                     Rarely
#
#                                       I've been feeling close to other people.   \
# URL Variable: sguid
# 58719067-43fe-11e8-8dd6-0a6b0cea1e1e                                       Often
# 3e850dd2-43f1-11e8-8dd6-0a6b0cea1e1e                            Some of the time
# 7e15f839-4412-11e8-8dd6-0a6b0cea1e1e                                       Often
# 2d35d4e3-4414-11e8-8dd6-0a6b0cea1e1e                                         NaN
# cad85f8d-44a2-11e8-8dd6-0a6b0cea1e1e                             All of the time
# ...                                                                          ...
# Tq7JzFnHzZtTRTj2                                                Some of the time
# FnafwU24WNsajpTZ                                                           Often
# IaIlEW6dlKxpu6SC                                                Some of the time
# J8FRqdya59eAx6Cv                                                           Often
# RrmjsV89nn5nri5Q                                                          Rarely
#
#                                       I've been feeling confident.  \
# URL Variable: sguid
# 58719067-43fe-11e8-8dd6-0a6b0cea1e1e                         Often
# 3e850dd2-43f1-11e8-8dd6-0a6b0cea1e1e                         Often
# 7e15f839-4412-11e8-8dd6-0a6b0cea1e1e                         Often
# 2d35d4e3-4414-11e8-8dd6-0a6b0cea1e1e                           NaN
# cad85f8d-44a2-11e8-8dd6-0a6b0cea1e1e              Some of the time
# ...                                                            ...
# Tq7JzFnHzZtTRTj2                                  Some of the time
# FnafwU24WNsajpTZ                                             Often
# IaIlEW6dlKxpu6SC                                             Often
# J8FRqdya59eAx6Cv                                             Often
# RrmjsV89nn5nri5Q                                  Some of the time
#
#                                       I've been able to make up my own mind about things.   \
# URL Variable: sguid
# 58719067-43fe-11e8-8dd6-0a6b0cea1e1e                                              Often
# 3e850dd2-43f1-11e8-8dd6-0a6b0cea1e1e                                    All of the time
# 7e15f839-4412-11e8-8dd6-0a6b0cea1e1e                                              Often
# 2d35d4e3-4414-11e8-8dd6-0a6b0cea1e1e                                                NaN
# cad85f8d-44a2-11e8-8dd6-0a6b0cea1e1e                                              Often
# ...                                                                                 ...
# Tq7JzFnHzZtTRTj2                                                       Some of the time
# FnafwU24WNsajpTZ                                                                  Often
# IaIlEW6dlKxpu6SC                                                                  Often
# J8FRqdya59eAx6Cv                                                        All of the time
# RrmjsV89nn5nri5Q                                                       Some of the time
#
#                                       I've been feeling loved.   \
# URL Variable: sguid
# 58719067-43fe-11e8-8dd6-0a6b0cea1e1e             All of the time
# 3e850dd2-43f1-11e8-8dd6-0a6b0cea1e1e                       Often
# 7e15f839-4412-11e8-8dd6-0a6b0cea1e1e             All of the time
# 2d35d4e3-4414-11e8-8dd6-0a6b0cea1e1e                         NaN
# cad85f8d-44a2-11e8-8dd6-0a6b0cea1e1e            Some of the time
# ...                                                          ...
# Tq7JzFnHzZtTRTj2                                Some of the time
# FnafwU24WNsajpTZ                                 All of the time
# IaIlEW6dlKxpu6SC                                           Often
# J8FRqdya59eAx6Cv                                           Often
# RrmjsV89nn5nri5Q                                Some of the time
#
#                                       I am interested in new things.   \
# URL Variable: sguid
# 58719067-43fe-11e8-8dd6-0a6b0cea1e1e                      All the time
# 3e850dd2-43f1-11e8-8dd6-0a6b0cea1e1e                      All the time
# 7e15f839-4412-11e8-8dd6-0a6b0cea1e1e                            Rarely
# 2d35d4e3-4414-11e8-8dd6-0a6b0cea1e1e                               NaN
# cad85f8d-44a2-11e8-8dd6-0a6b0cea1e1e                             Often
# ...                                                                ...
# Tq7JzFnHzZtTRTj2                                                 Often
# FnafwU24WNsajpTZ                                                 Often
# IaIlEW6dlKxpu6SC                                                 Often
# J8FRqdya59eAx6Cv                                                 Often
# RrmjsV89nn5nri5Q                                                Rarely
#
#                                       I've been feeling cheerful. 
# URL Variable: sguid
# 58719067-43fe-11e8-8dd6-0a6b0cea1e1e               Some of the time
# 3e850dd2-43f1-11e8-8dd6-0a6b0cea1e1e               Some of the time
# 7e15f839-4412-11e8-8dd6-0a6b0cea1e1e               Some of the time
# 2d35d4e3-4414-11e8-8dd6-0a6b0cea1e1e                            NaN
# cad85f8d-44a2-11e8-8dd6-0a6b0cea1e1e               Some of the time
# ...                                                             ...
# Tq7JzFnHzZtTRTj2                                              Often
# FnafwU24WNsajpTZ                                              Often
# IaIlEW6dlKxpu6SC                                   Some of the time
# J8FRqdya59eAx6Cv                                              Often
# RrmjsV89nn5nri5Q                                   Some of the time
#
# [692 rows x 301 columns]

# %%
# Here we will merge all of the different ceremony timepoints into one data frame. 

ceremony = pd.concat([ceremony_baseline, ceremony_acute_1, ceremony_acute_2, ceremony_acute_3, ceremony_acute_4, ceremony_acute_5, ceremony_post], axis=1)
ceremony
# Out:
#                                       Response ID              Time Started  \
# URL Variable: sguid
# 7a98da5c-4730-11e8-9573-0a6b0cea1e1e         13.0  Apr 24, 2018 12:29:23 am
# 9c32d3ac-495b-11e8-9573-0a6b0cea1e1e         15.0  Apr 29, 2018 12:12:10 am
# 5d2fa944-446c-11e8-8dd6-0a6b0cea1e1e         16.0   Apr 29, 2018 7:37:06 am
# ddd2134c-4474-11e8-8dd6-0a6b0cea1e1e         17.0   Apr 29, 2018 7:18:54 pm
# b2777e3a-496b-11e8-9573-0a6b0cea1e1e         18.0    May 1, 2018 6:09:56 pm
# ...                                           ...                       ...
# aevYjVTsZmAhelHj                              NaN                       NaN
# lmKLPF5QLzWw2OhKU7                            NaN                       NaN
# Fr4aE61apaKrEq5U                              NaN                       NaN
# lmA7hxK4wt6w1u1286                            NaN                       NaN
# lmMRpLjWiNA4m5kLUo                            NaN                       NaN
#
#                                                Date Submitted Language  \
# URL Variable: sguid
# 7a98da5c-4730-11e8-9573-0a6b0cea1e1e  Apr 24, 2018 7:08:19 pm  English
# 9c32d3ac-495b-11e8-9573-0a6b0cea1e1e  May 8, 2018 10:26:10 am  English
# 5d2fa944-446c-11e8-8dd6-0a6b0cea1e1e  Apr 29, 2018 9:30:13 am  English
# ddd2134c-4474-11e8-8dd6-0a6b0cea1e1e  Apr 29, 2018 8:17:09 pm  English
# b2777e3a-496b-11e8-9573-0a6b0cea1e1e   May 1, 2018 6:50:53 pm  English
# ...                                                       ...      ...
# aevYjVTsZmAhelHj                                          NaN      NaN
# lmKLPF5QLzWw2OhKU7                                        NaN      NaN
# Fr4aE61apaKrEq5U                                          NaN      NaN
# lmA7hxK4wt6w1u1286                                        NaN      NaN
# lmMRpLjWiNA4m5kLUo                                        NaN      NaN
#
#                                                              SessionID  Tags  \
# URL Variable: sguid
# 7a98da5c-4730-11e8-9573-0a6b0cea1e1e  aee0774480867ca42c2b4ff987464d49   NaN
# 9c32d3ac-495b-11e8-9573-0a6b0cea1e1e  3673ef6c5df20bae846025e244dcb1c8   NaN
# 5d2fa944-446c-11e8-8dd6-0a6b0cea1e1e  199b8ace0124d5f6a94a6d1b1a3d51c3   NaN
# ddd2134c-4474-11e8-8dd6-0a6b0cea1e1e  6c85085ea3d4da7422922eb3e4cbce3b   NaN
# b2777e3a-496b-11e8-9573-0a6b0cea1e1e  faedd886904dee3e8b70239e72b8e3df   NaN
# ...                                                                ...   ...
# aevYjVTsZmAhelHj                                                   NaN   NaN
# lmKLPF5QLzWw2OhKU7                                                 NaN   NaN
# Fr4aE61apaKrEq5U                                                   NaN   NaN
# lmA7hxK4wt6w1u1286                                                 NaN   NaN
# lmMRpLjWiNA4m5kLUo                                                 NaN   NaN
#
#                                          IP Address  Longitude   Latitude  \
# URL Variable: sguid
# 7a98da5c-4730-11e8-9573-0a6b0cea1e1e    86.4.254.35     0.2000  51.583302
# 9c32d3ac-495b-11e8-9573-0a6b0cea1e1e  79.68.155.177    -0.0667  51.666698
# 5d2fa944-446c-11e8-8dd6-0a6b0cea1e1e   81.101.58.48    -0.0333  51.599998
# ddd2134c-4474-11e8-8dd6-0a6b0cea1e1e   81.101.58.48    -0.0333  51.599998
# b2777e3a-496b-11e8-9573-0a6b0cea1e1e    86.26.64.34    -0.2667  51.599998
# ...                                             ...        ...        ...
# aevYjVTsZmAhelHj                                NaN        NaN        NaN
# lmKLPF5QLzWw2OhKU7                              NaN        NaN        NaN
# Fr4aE61apaKrEq5U                                NaN        NaN        NaN
# lmA7hxK4wt6w1u1286                              NaN        NaN        NaN
# lmMRpLjWiNA4m5kLUo                              NaN        NaN        NaN
#
#                                              Country  ...  \
# URL Variable: sguid                                   ...
# 7a98da5c-4730-11e8-9573-0a6b0cea1e1e  United Kingdom  ...
# 9c32d3ac-495b-11e8-9573-0a6b0cea1e1e  United Kingdom  ...
# 5d2fa944-446c-11e8-8dd6-0a6b0cea1e1e  United Kingdom  ...
# ddd2134c-4474-11e8-8dd6-0a6b0cea1e1e  United Kingdom  ...
# b2777e3a-496b-11e8-9573-0a6b0cea1e1e  United Kingdom  ...
# ...                                              ...  ...
# aevYjVTsZmAhelHj                                 NaN  ...
# lmKLPF5QLzWw2OhKU7                               NaN  ...
# Fr4aE61apaKrEq5U                                 NaN  ...
# lmA7hxK4wt6w1u1286                               NaN  ...
# lmMRpLjWiNA4m5kLUo                               NaN  ...
#
#                                      I've had energy to spare.  \
# URL Variable: sguid
# 7a98da5c-4730-11e8-9573-0a6b0cea1e1e                       NaN
# 9c32d3ac-495b-11e8-9573-0a6b0cea1e1e                       NaN
# 5d2fa944-446c-11e8-8dd6-0a6b0cea1e1e                       NaN
# ddd2134c-4474-11e8-8dd6-0a6b0cea1e1e                       NaN
# b2777e3a-496b-11e8-9573-0a6b0cea1e1e                       NaN
# ...                                                        ...
# aevYjVTsZmAhelHj                                         Often
# lmKLPF5QLzWw2OhKU7                                       Often
# Fr4aE61apaKrEq5U                              Some of the time
# lmA7hxK4wt6w1u1286                            Some of the time
# lmMRpLjWiNA4m5kLUo                            Some of the time
#
#                                      I've been dealing with problems well.   \
# URL Variable: sguid
# 7a98da5c-4730-11e8-9573-0a6b0cea1e1e                                     NaN
# 9c32d3ac-495b-11e8-9573-0a6b0cea1e1e                                     NaN
# 5d2fa944-446c-11e8-8dd6-0a6b0cea1e1e                                     NaN
# ddd2134c-4474-11e8-8dd6-0a6b0cea1e1e                                     NaN
# b2777e3a-496b-11e8-9573-0a6b0cea1e1e                                     NaN
# ...                                                                      ...
# aevYjVTsZmAhelHj                                                       Often
# lmKLPF5QLzWw2OhKU7                                                     Often
# Fr4aE61apaKrEq5U                                            Some of the time
# lmA7hxK4wt6w1u1286                                                     Often
# lmMRpLjWiNA4m5kLUo                                                     Often
#
#                                      I've been thinking clearly.  \
# URL Variable: sguid
# 7a98da5c-4730-11e8-9573-0a6b0cea1e1e                         NaN
# 9c32d3ac-495b-11e8-9573-0a6b0cea1e1e                         NaN
# 5d2fa944-446c-11e8-8dd6-0a6b0cea1e1e                         NaN
# ddd2134c-4474-11e8-8dd6-0a6b0cea1e1e                         NaN
# b2777e3a-496b-11e8-9573-0a6b0cea1e1e                         NaN
# ...                                                          ...
# aevYjVTsZmAhelHj                                 All of the time
# lmKLPF5QLzWw2OhKU7                                         Often
# Fr4aE61apaKrEq5U                                           Often
# lmA7hxK4wt6w1u1286                              Some of the time
# lmMRpLjWiNA4m5kLUo                                         Often
#
#                                       I've been feeling good about myself.   \
# URL Variable: sguid
# 7a98da5c-4730-11e8-9573-0a6b0cea1e1e                                     NaN
# 9c32d3ac-495b-11e8-9573-0a6b0cea1e1e                                     NaN
# 5d2fa944-446c-11e8-8dd6-0a6b0cea1e1e                                     NaN
# ddd2134c-4474-11e8-8dd6-0a6b0cea1e1e                                     NaN
# b2777e3a-496b-11e8-9573-0a6b0cea1e1e                                     NaN
# ...                                                                      ...
# aevYjVTsZmAhelHj                                                       Often
# lmKLPF5QLzWw2OhKU7                                          Some of the time
# Fr4aE61apaKrEq5U                                                       Often
# lmA7hxK4wt6w1u1286                                                     Often
# lmMRpLjWiNA4m5kLUo                                                     Often
#
#                                       I've been feeling close to other people.   \
# URL Variable: sguid
# 7a98da5c-4730-11e8-9573-0a6b0cea1e1e                                         NaN
# 9c32d3ac-495b-11e8-9573-0a6b0cea1e1e                                         NaN
# 5d2fa944-446c-11e8-8dd6-0a6b0cea1e1e                                         NaN
# ddd2134c-4474-11e8-8dd6-0a6b0cea1e1e                                         NaN
# b2777e3a-496b-11e8-9573-0a6b0cea1e1e                                         NaN
# ...                                                                          ...
# aevYjVTsZmAhelHj                                                 All of the time
# lmKLPF5QLzWw2OhKU7                                              Some of the time
# Fr4aE61apaKrEq5U                                                          Rarely
# lmA7hxK4wt6w1u1286                                                         Often
# lmMRpLjWiNA4m5kLUo                                                         Often
#
#                                       I've been feeling confident.  \
# URL Variable: sguid
# 7a98da5c-4730-11e8-9573-0a6b0cea1e1e                           NaN
# 9c32d3ac-495b-11e8-9573-0a6b0cea1e1e                           NaN
# 5d2fa944-446c-11e8-8dd6-0a6b0cea1e1e                           NaN
# ddd2134c-4474-11e8-8dd6-0a6b0cea1e1e                           NaN
# b2777e3a-496b-11e8-9573-0a6b0cea1e1e                           NaN
# ...                                                            ...
# aevYjVTsZmAhelHj                                             Often
# lmKLPF5QLzWw2OhKU7                                Some of the time
# Fr4aE61apaKrEq5U                                             Often
# lmA7hxK4wt6w1u1286                                           Often
# lmMRpLjWiNA4m5kLUo                                           Often
#
#                                       I've been able to make up my own mind about things.   \
# URL Variable: sguid
# 7a98da5c-4730-11e8-9573-0a6b0cea1e1e                                                NaN
# 9c32d3ac-495b-11e8-9573-0a6b0cea1e1e                                                NaN
# 5d2fa944-446c-11e8-8dd6-0a6b0cea1e1e                                                NaN
# ddd2134c-4474-11e8-8dd6-0a6b0cea1e1e                                                NaN
# b2777e3a-496b-11e8-9573-0a6b0cea1e1e                                                NaN
# ...                                                                                 ...
# aevYjVTsZmAhelHj                                                       Some of the time
# lmKLPF5QLzWw2OhKU7                                                                Often
# Fr4aE61apaKrEq5U                                                                  Often
# lmA7hxK4wt6w1u1286                                                                Often
# lmMRpLjWiNA4m5kLUo                                                      All of the time
#
#                                       I've been feeling loved.   \
# URL Variable: sguid
# 7a98da5c-4730-11e8-9573-0a6b0cea1e1e                         NaN
# 9c32d3ac-495b-11e8-9573-0a6b0cea1e1e                         NaN
# 5d2fa944-446c-11e8-8dd6-0a6b0cea1e1e                         NaN
# ddd2134c-4474-11e8-8dd6-0a6b0cea1e1e                         NaN
# b2777e3a-496b-11e8-9573-0a6b0cea1e1e                         NaN
# ...                                                          ...
# aevYjVTsZmAhelHj                                           Often
# lmKLPF5QLzWw2OhKU7                              Some of the time
# Fr4aE61apaKrEq5U                                           Often
# lmA7hxK4wt6w1u1286                              Some of the time
# lmMRpLjWiNA4m5kLUo                              Some of the time
#
#                                       I am interested in new things.   \
# URL Variable: sguid
# 7a98da5c-4730-11e8-9573-0a6b0cea1e1e                               NaN
# 9c32d3ac-495b-11e8-9573-0a6b0cea1e1e                               NaN
# 5d2fa944-446c-11e8-8dd6-0a6b0cea1e1e                               NaN
# ddd2134c-4474-11e8-8dd6-0a6b0cea1e1e                               NaN
# b2777e3a-496b-11e8-9573-0a6b0cea1e1e                               NaN
# ...                                                                ...
# aevYjVTsZmAhelHj                                                 Often
# lmKLPF5QLzWw2OhKU7                                    Some of the time
# Fr4aE61apaKrEq5U                                                 Often
# lmA7hxK4wt6w1u1286                                    Some of the time
# lmMRpLjWiNA4m5kLUo                                               Often
#
#                                       I've been feeling cheerful. 
# URL Variable: sguid
# 7a98da5c-4730-11e8-9573-0a6b0cea1e1e                            NaN
# 9c32d3ac-495b-11e8-9573-0a6b0cea1e1e                            NaN
# 5d2fa944-446c-11e8-8dd6-0a6b0cea1e1e                            NaN
# ddd2134c-4474-11e8-8dd6-0a6b0cea1e1e                            NaN
# b2777e3a-496b-11e8-9573-0a6b0cea1e1e                            NaN
# ...                                                             ...
# aevYjVTsZmAhelHj                                              Often
# lmKLPF5QLzWw2OhKU7                                 Some of the time
# Fr4aE61apaKrEq5U                                              Often
# lmA7hxK4wt6w1u1286                                            Often
# lmMRpLjWiNA4m5kLUo                                 Some of the time
#
# [975 rows x 1137 columns]

# %% [markdown]
# ## Renaming columns

# %%
datasets = [ceremony_acute_1, ceremony_acute_2, ceremony_acute_3, ceremony_acute_4, ceremony_acute_5]

renames_dfs = []

for dataset in datasets:
    dataset.rename(
        columns={
            ## MEQ 
             'Freedom from the limitations of your personal self and feeling a unity or bond with what was felt to be greater than your personal self.': 'MEQ1',
             'Experience of pure being and pure awareness (beyond the world of sense impressions).': 'MEQ2',
             'Experience of oneness in relation to an "inner world" within.': 'MEQ3',
             'Experience of the fusion of your personal self into a larger whole.': 'MEQ4',
             'Experience of unity with ultimate reality.': 'MEQ5',
             'Feeling that you experienced eternity or infinity.': 'MEQ6',
             """Experience of oneness or unity with objects and/or persons perceived in your surroundings.""": 'MEQ7',
             """Experience of the insight that "all is One".""": 'MEQ8',
             'Awareness of the life or living presence in all things.': 'MEQ9',
             'Gain of insightful knowledge experienced at an intuitive level.': 'MEQ10',
             'Certainty of encounter with ultimately reality (in sense of being able to "know" and "see" what is really real at some point during your experience).': 'MEQ11',
             'You are convinced now, as you look back on your experience, that in it you encountered ultimate reality (i.e. that you "knew" and "saw" what was really real).': 'MEQ12',
             'Sense of being at a spiritual height.': 'MEQ13',
             'Sense of Reverence.': 'MEQ14',
             'Feeling that you experienced something profoundly sacred and holy.': 'MEQ15',
             'Experience of amazement.': 'MEQ16',
             'Feelings of tenderness and gentleness.': 'MEQ17',
             'Feelings of peace and tranquillity.': 'MEQ18',
             'Experience of ecstasy.': 'MEQ19',
             'Sense of awe or awesomeness.': 'MEQ20',
             'Feelings of joy.': 'MEQ21',
             'Loss of your usual sense of time.': 'MEQ22',
             'Loss of your usual sense of space.': 'MEQ23',
             'Loss of usual awareness of where you were.': 'MEQ24',
             'Sense of being "outside of" time, beyond past and future.': 'MEQ25',
             'Being in a realm with no space boundaries.': 'MEQ26',
             'Experience of timelessness.': 'MEQ27',
             'Sense that the experience cannot be described adequately in words.': 'MEQ28',
             'Feeling that you could not do justice to your experience by describing it in words.': 'MEQ29',
             'Feeling that it would be difficult to communicate your own experience to others who have not had similar experiences.': 'MEQ30',
            ## EDI
             'I felt especially assertive ': 'EDI1',
             'I experienced a dissolution of my "self" or ego.': 'EDI2',
             'I felt more important or special than others': 'EDI3',
             'I felt at one with the universe.': 'EDI4',
             'My ego felt inflated': 'EDI5',
             'I felt a sense of union with others.': 'EDI6',
             'I felt especially sure-of-myself ': 'EDI7',
             'I experienced a decrease in my sense of self-importance.': 'EDI8',
             'I felt especially keen and competitive': 'EDI9',
             'I experienced a disintegration of my "self" or ego.': 'EDI10',
             "I felt like my viewpoint was worth more than other peoples'": 'EDI11',
             'I felt far less absorbed by my own issues and concerns.': 'EDI12',
             'I felt especially self-confident': 'EDI13',
             'I lost all sense of ego.': 'EDI14',
             'I felt especially self-assured': 'EDI15',
             'All notion of self and identity dissolved away.': 'EDI16',
            ## EBI
             'I faced emotionally difficult feelings that I usually push aside.': 'EBI1',
             """I experienced a resolution of a personal conflict/trauma""": 'EBI2',
             'I felt able to explore challenging emotions and memories.': 'EBI3',
             'I was resisting and avoiding challenging feelings throughout, without breakthrough.': 'EBI4',
             'I had an emotional breakthrough. ': 'EBI5',
             'I was able to get a sense of closure on an emotional problem.': 'EBI6',
             'I felt emotionally stuck throughout, without breakthrough.': 'EBI7',
             'I achieved an emotional release followed by a sense of relief.': 'EBI8',
            ## CEQ            
             'Isolation and loneliness': 'CEQ1',
             'Sadness': 'CEQ2',
             'Feeling my heart beating': 'CEQ3',
             'I had the feeling something horrible would happen': 'CEQ4',
             """Feeling my body shake/tremble""": 'CEQ5',
             'Feelings of grief': 'CEQ6',
             'Experience of fear': 'CEQ7',
             'Fear that I might lose my mind or go insane': 'CEQ8',
             'I felt like crying': 'CEQ9',
             'Feeling of isolation from people and things': 'CEQ10',
             'Feelings of despair': 'CEQ11',
             'I had the feeling that people were plotting against me': 'CEQ12',
             'I was afraid that the state I was in would last forever': 'CEQ13',
             'Anxiousness': 'CEQ14',
             'I felt shaky inside': 'CEQ15',
             'I had the profound experience of my own death': 'CEQ16',
             'I felt my heart beating irregularly or skipping beats ': 'CEQ17',
             'Pressure or weight in my chest or abdomen': 'CEQ18',
             'I experienced a decreased sense of sanity ': 'CEQ19',
             'I felt as if I was dead or dying': 'CEQ20',
             'Panic': 'CEQ21',
             'Experience of antagonism toward people around me': 'CEQ22',
             'Despair': 'CEQ23',
             'I felt isolated from everything and everyone': 'CEQ24',
             """Emotional and/or physical suffering""": 'CEQ25',
             'I felt frightened': 'CEQ26',
            ## ASC
             'I saw regular patterns in complete darkness or with closed eyes.': 'ASC1',
             'I saw colours in complete darkness or with closed eyes.': 'ASC2',
             'I saw brightness or flashes in complete darkness or with closed eyes.': 'ASC3',
             'I saw whole scenes roll by with closed eyes or in complete darkness.': 'ASC4',
             'I could see images from my memory or imagination with extreme clarity.': 'ASC5',
             'My imagination was extremely vivid.': 'ASC6',
             'Sounds seemed to influence what I saw.': 'ASC7',
             'Shapes seemed to be changed by sounds or noises.': 'ASC8',
             'The colors of things seemed to be altered by sounds or noises.': 'ASC9'
    
    }, inplace=True)

# %%
ceremony_acute_1 = ceremony_acute_1.add_suffix('_1')
ceremony_acute_2 = ceremony_acute_2.add_suffix('_2')
ceremony_acute_3 = ceremony_acute_3.add_suffix('_3')
ceremony_acute_4 = ceremony_acute_4.add_suffix('_4')
ceremony_acute_5 = ceremony_acute_5.add_suffix('_5')

# %%
ceremony_acute_5.columns.tolist()
# Out:
# ['Response ID_5',
#  'Time Started_5',
#  'Date Submitted_5',
#  'Status_5',
#  'Language_5',
#  'SessionID_5',
#  'IP Address_5',
#  'Longitude_5',
#  'Latitude_5',
#  'Country_5',
#  'City_5',
#  'State/Region_5',
#  'Postal_5',
#  'New Hidden Value_5',
#  'What was the actual amount of time between completing the previous questionnaire (the one you did just before the ceremony) and the intake of the psychedelic / plant medicine?_5',
#  'Can you indicate what (total) dose you used? To standardise responses, we will ask you to answer in reference to the typical dose that was given during the ceremony.  If you asked for or received a smaller or higher dose than what was handed out, please indicate the appropriate answer below. If you do not know what dose you have received, you could consider asking the facilitator or shaman.  _5',
#  'How many psychedelic / plant medicine intakes occurred over the course of the session / ceremony?  _5',
#  'Cannabis:Can you indicate what other types of substances / plant medicines (incl. the dose) you used during the ceremony?_5',
#  'Alcohol:Can you indicate what other types of substances / plant medicines (incl. the dose) you used during the ceremony?_5',
#  'Kambo:Can you indicate what other types of substances / plant medicines (incl. the dose) you used during the ceremony?_5',
#  'Tobacco:Can you indicate what other types of substances / plant medicines (incl. the dose) you used during the ceremony?_5',
#  'Sananga:Can you indicate what other types of substances / plant medicines (incl. the dose) you used during the ceremony?_5',
#  'Coca:Can you indicate what other types of substances / plant medicines (incl. the dose) you used during the ceremony?_5',
#  'Rapé:Can you indicate what other types of substances / plant medicines (incl. the dose) you used during the ceremony?_5',
#  '1. Seeing bursts of light or splashes of colour._5',
#  '2. Seeing abstract geometrical designs and patterns._5',
#  '3. Seeing rapidly transforming objects/figures._5',
#  '4. Seeing repetitive, moving objects/figures embedded in geometrical patterns._5',
#  '5. Seeing stable, well-defined objects/figures_5',
#  '6. Seeing snapshots or glimpses of full scenes._5',
#  '7. Seeing full-fledged scenes without being part of them, similar to watching a movie._5',
#  '8. Being fully immersed within what looked and felt like another authentic realm._5',
#  '9. Being surrounded by a supreme white light._5',
#  '10. Visions with personal/autobiographic material._5',
#  '11. Interacting with beings/entities in your visions._5',
#  '12. Visions with sacred or divine themes._5',
#  '13. Visions with carnivalesque or tricksterish themes._5',
#  '14. Visions with demonic or evil themes._5',
#  '15. Visions of nature, animals or plants._5',
#  '16. Important knowledge being conveyed to you through your visions._5',
#  '17. Visions progressing over time from simple (busts/splashes/geometries) to complex (well-defined objects/figures) images._5',
#  '18. Visions progressing over time from isolated elements to full, immersive scenes._5',
#  'MEQ1_5',
#  'MEQ2_5',
#  'MEQ3_5',
#  'MEQ4_5',
#  'MEQ5_5',
#  'MEQ6_5',
#  'MEQ7_5',
#  'MEQ8_5',
#  'MEQ9_5',
#  'MEQ10_5',
#  'MEQ11_5',
#  'MEQ12_5',
#  'MEQ13_5',
#  'MEQ14_5',
#  'MEQ15_5',
#  'MEQ16_5',
#  'MEQ17_5',
#  'MEQ18_5',
#  'MEQ19_5',
#  'MEQ20_5',
#  'MEQ21_5',
#  'MEQ22_5',
#  'MEQ23_5',
#  'MEQ24_5',
#  'MEQ25_5',
#  'MEQ26_5',
#  'MEQ27_5',
#  'MEQ28_5',
#  'MEQ29_5',
#  'MEQ30_5',
#  'EDI1_5',
#  'EDI2_5',
#  'EDI3_5',
#  'EDI4_5',
#  'EDI5_5',
#  'EDI6_5',
#  'EDI7_5',
#  'EDI8_5',
#  'EDI9_5',
#  'EDI10_5',
#  'EDI11_5',
#  'EDI12_5',
#  'EDI13_5',
#  'EDI14_5',
#  'EDI15_5',
#  'EDI16_5',
#  'EBI1_5',
#  'EBI2_5',
#  'EBI3_5',
#  'EBI4_5',
#  'EBI5_5',
#  'EBI6_5',
#  'EBI7_5',
#  'EBI8_5',
#  'CEQ1_5',
#  'CEQ2_5',
#  'CEQ3_5',
#  'CEQ4_5',
#  'CEQ5_5',
#  'CEQ6_5',
#  'CEQ7_5',
#  'CEQ8_5',
#  'CEQ9_5',
#  'CEQ10_5',
#  'CEQ11_5',
#  'CEQ12_5',
#  'CEQ13_5',
#  'CEQ14_5',
#  'CEQ15_5',
#  'CEQ16_5',
#  'CEQ17_5',
#  'CEQ18_5',
#  'CEQ19_5',
#  'CEQ20_5',
#  'CEQ21_5',
#  'CEQ22_5',
#  'CEQ23_5',
#  'CEQ24_5',
#  'CEQ25_5',
#  'CEQ26_5',
#  'ASC1_5',
#  'ASC2_5',
#  'ASC3_5',
#  'ASC4_5',
#  'ASC5_5',
#  'ASC6_5',
#  'ASC7_5',
#  'ASC8_5',
#  'ASC9_5',
#  'Nausea or vomiting:Have you experienced any of the following bodily effects during the session / ceremony: _5',
#  'Diarrhea:Have you experienced any of the following bodily effects during the session / ceremony: _5',
#  'Body aches:Have you experienced any of the following bodily effects during the session / ceremony: _5',
#  'Ringing in the ears:Have you experienced any of the following bodily effects during the session / ceremony: _5',
#  'Headache:Have you experienced any of the following bodily effects during the session / ceremony: _5',
#  'Sweats or chills:Have you experienced any of the following bodily effects during the session / ceremony: _5',
#  'Trembling:Have you experienced any of the following bodily effects during the session / ceremony: _5',
#  'Crying:Have you experienced any of the following bodily effects during the session / ceremony: _5',
#  'Did you experience the vomiting, diarrhea, sweating or crying as transformative (i.e. cleansing, or "purging")?_5']

# %% [markdown]
# ## Exporting the created dataframes to excel

# %%
# This exports our dataframe into excel format.
# We need to specify which dataframe we want to export, 
# And in brackets provide the name of the new excel file 
# that we want to create. 

c1.to_excel("cohort1_merged.xlsx")
c2.to_excel("cohort2_merged.xlsx")
c1_c2.to_excel("c1_c2_merged.xlsx")
ceremony.to_excel("ceremony_merged.xlsx")

# %%
# Now let's look at the ceremony data. 
# Because we have 5 acute timepoints we want to take a mean out of, 
# we need to rename columns into simple names with consistent spelling
# to make it easy to specify which ones we want to take a mean out of: 

columns = ceremony_acute_1.columns.values.tolist()
columns

# %%
#Find differences in columns names between c1 and c2
#First for baseline

c1_baseline_cols = c1_baseline.columns
c2_baseline_cols = c2_baseline.columns

common_baseline_cols = c1_baseline_cols.intersection(c2_baseline_cols)
c1_not_c2_baseline_cols = c1_baseline_cols.difference(c2_baseline_cols)

c1_not_c2_baseline_cols

differences = (ceremony_acute_1.columns).difference(ceremony_acute_2.columns)
differences

# %%
ceremony.columns.duplicated()

# %% [markdown]
# ## Recoding data

# %%
c1_c2.corr()

# %%
c1_baseline.columns.to_list()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/3q/48mdcsy943s70056l21l837h0000gn/T/ipykernel_97745/2475857384.py in <module>
# ----> 1 c1_baseline.columns.to_list()
#
# NameError: name 'c1_baseline' is not defined

# %% [markdown]
# ## Correlations

# %%
import seaborn as sns

correlations = c1_c2.corr()

# plot the heatmap and annotation on it
sns.heatmap(correlations, xticklabels=correlations.columns, yticklabels=correlations.columns, annot=True)

# %%
df3.set_index('col1', inplace=True)
df3

# %%
full_df = pd.concat([new_df, df3], axis=0)
full_df

# %%
full_df = full_df.rename(columns={'col2': 'ssri', 'col3': 'openness', 'col6':'happy'})
full_df

# %%
full_df['happy'] = (full_df['happy']
                    .str.replace('yes','1')
                    .str.replace('no','0'))
full_df

# %%
full_df.dtypes

# %%
full_df = full_df.astype(float)
full_df

# %%
full_df.dtypes

# %%
full_df.corr()

# %%
import seaborn as sns

Var_Corr = full_df.corr()
# plot the heatmap and annotation on it
sns.heatmap(Var_Corr, xticklabels=Var_Corr.columns, yticklabels=Var_Corr.columns, annot=True)
